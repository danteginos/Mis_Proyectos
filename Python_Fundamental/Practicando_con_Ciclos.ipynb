# %% [markdown]
# ## Practicando con ciclos (Práctica)
#    Ejercicios Prácticos
#
#   * Ejercicio 1: Gestión de Inventario
#
# 1. Crea un diccionario para gestionar el inventario de una tienda. Las claves del diccionario deben ser los nombres de los productos y los valores deben ser la cantidad de cada producto en inventario.
# 2. Usa un bucle for para mostrar todos los productos y sus cantidades.
# 3. Actualiza la cantidad de un producto específico.
# 4. Agrega un nuevo producto al inventario.
# 5. Elimina un producto del inventario.

# %%
inventario = {"Pantalon":50,
              "Camisa":20,
              "Corbata":15,
              "Falda":12,
              "Blusa":40
             }
for nombre, cantidad in inventario.items():
     print(f" Producto :{nombre}, Unidades : {cantidad}")

# Actualiza la cantidad de Camisas
inventario["Camisa"]= 12
print(inventario)

# Agrega un producto al inventario
inventario["Zapato"]=60

nombre = "Chaqueta"
cantidad = 300
inventario[nombre]=cantidad
print(inventario)

# Elimina un producto del inventario
del inventario["Zapato"]

# Mostrar el inventario actualizado
for nombre, cantidad in inventario.items():
    print(f" Producto : {nombre}, Cantidad : {cantidad}")
# Out:
#  Producto :Pantalon, Unidades : 50
#  Producto :Camisa, Unidades : 20
#  Producto :Corbata, Unidades : 15
#  Producto :Falda, Unidades : 12
#  Producto :Blusa, Unidades : 40
# {'Pantalon': 50, 'Camisa': 12, 'Corbata': 15, 'Falda': 12, 'Blusa': 40}
# {'Pantalon': 50, 'Camisa': 12, 'Corbata': 15, 'Falda': 12, 'Blusa': 40, 'Zapato': 60, 'Chaqueta': 300}
#  Producto : Pantalon, Cantidad : 50
#  Producto : Camisa, Cantidad : 12
#  Producto : Corbata, Cantidad : 15
#  Producto : Falda, Cantidad : 12
#  Producto : Blusa, Cantidad : 40
#  Producto : Chaqueta, Cantidad : 300

# %% [markdown]
# ## Ejercicio 2: Procesamiento de Datos de Estudiantes
#
# 1. Crea una lista de tuplas donde cada tupla contenga el nombre de un estudiante y su calificación en un examen.
# 2. Usa un bucle for para mostrar todos los nombres y calificaciones.
# 3. Calcula y muestra la calificación promedio.
# 4. Encuentra y muestra la calificación más alta y la más baja.

# %% [markdown]
# ### Creación de la lista de tuplas con nombres y calificaciones

# %%
# Cracion de la lista de tuplas con nombre y calificacion
estudiantes = [("Juan",5.6), ("Pedro", 4.1), ("Maria", 3.7), ("Pepe", 7.0)]

# %% [markdown]
# ### Mostrar todos los nombres y calificaciones

# %%
# Mostrar todos los nombres y califaciones

for nombre, calificacion in estudiantes:
    print(f"Nombre : {nombre}, Calificación : {calificacion:.1f}")
# Out:
# Nombre : Juan, Calificación : 5.6
# Nombre : Pedro, Calificación : 4.1
# Nombre : Maria, Calificación : 3.7
# Nombre : Pepe, Calificación : 7.0

# %% [markdown]
# ### Calcular la calificación promedio

# %%
# Calcular la calificación promedio
#suma = 0
#for nombre, calificacion in estudiantes:
#    suma += calificacion
#promedio = suma / len(estudiantes)
#print(f"Calificación Promedio : {promedio:.2f}")

suma_calificaciones = sum(calificacion for nombre, calificacion in estudiantes)
promedio = suma_calificaciones / len(estudiantes)
print(f"\nCalificación promedio: {promedio:.2f}")
# Out:
# Calificación promedio: 5.10

# %% [markdown]
# ### Encontrar la calificación más alta y más baja

# %%
# Encontrar la calificación más alta y más baja

#calificaciones = []
#for nombre, calificacion in estudiantes:
#    calificaciones.append(calificacion)
#maxima = max(calificaciones)
#minima = min(calificaciones)
#print(f"Calificacion mas alta : {maxima:.1f}")
#print(f"Calificacion mas baja : {minima:.1f}")


calificaciones = [calificacion for nombre, calificacion in estudiantes]
calificacion_maxima = max(calificaciones)
calificacion_minima = min(calificaciones)
print(f"Calificación más alta: {calificacion_maxima}")
print(f"Calificación más baja: {calificacion_minima}")
# Out:
# Calificación más alta: 7.0
# Calificación más baja: 3.7

# %% [markdown]
# ### Ejercicio 3: Registro de Ventas
#
# 1. Crea un diccionario donde las claves sean los nombres de los vendedores y los valores sean listas de ventas realizadas por cada vendedor en una semana.
# 2. Usa un bucle for para mostrar el total de ventas de cada vendedor.
# 3. Calcula y muestra el vendedor con el mayor total de ventas.

# %% [markdown]
# ### Creación del diccionario de ventas

# %%
# Creación del diccionario de ventas
ventas = {
    "Carlos": [100, 200, 150, 300, 250, 400, 350],
    "María": [200, 300, 250, 350, 300, 450, 500],
    "Luis": [150, 250, 200, 300, 350, 400, 450],
    "Ana": [300, 350, 400, 450, 500, 550, 600]
}

# %% [markdown]
# ### Usa un bucle for para mostrar el total de ventas de cada vendedor.

# %%
# total de ventas de cada vendedor
#for nombre, lista in ventas.items():
#    suma = 0
#    for i in range(0, len(lista)):
#        suma += lista[i]
#    print(f"Vendedor : {nombre}, Total de ventas : {suma}")


for vendedor, lista_ventas in ventas.items():
    total_ventas = sum(lista_ventas)
    print(f"{vendedor}: {total_ventas}")
# Out:
# Carlos: 1750
# María: 2350
# Luis: 2100
# Ana: 3150

# %% [markdown]
# ### Calcular y mostrar el vendedor con el mayor total de ventas

# %%
# Calcular y mostrar el vendedor con el mayor total de ventas
#nombre = ""
#mayor = 0
#for vendedor, lista_ventas in ventas.items():
#     total_venta=sum(lista_ventas)
#     if total_venta > mayor:
#        nombre = vendedor
#        mayor = total_venta
#print(f" Vendedor : {nombre} con mayor venta : {mayor}")


# Calcular y mostrar el vendedor con el mayor total de ventas
ventas_totales = {vendedor: sum(lista_ventas) for vendedor, lista_ventas in ventas.items()}
vendedor_maximo = max(ventas_totales, key=ventas_totales.get)
print(f"Vendedor con el mayor total de ventas: {vendedor_maximo} con {ventas_totales[vendedor_maximo]} ventas")
# Out:
# Vendedor con el mayor total de ventas: Ana con 3150 ventas
