# %% [markdown]
# ## Ejercicio 1 : Saludo Personalizado

# %%
nombre = input("¿ Ingrese su nombre: ")         #   Pide nombre de usuario
edad = int(input("¿ Ingrese su edad:  "))       #   Pide edad de usurio, edad se convierte a entero
print("")
print(f" Bienvenido {nombre} su edad es {edad}!")     # se despliega mensaje con los datos del usuario con formato
# Out:
# ¿ Ingrese su nombre: maciel
# ¿ Ingrese su edad:  34
#
#  Bienvenido maciel su edad es 34!

# %% [markdown]
# ## Ejercicio 2 : Manipulación de cadenas

# %%
nombre_completo = "Dante Gino Silva Santis"
print("")
print(f"Tu Nombre completo en Mayuscula es {nombre_completo.upper()}")              # convierte la cadena a Mayusculas con metodo upper() e imprime
print("")
print(f"Tu Nombre completo en Minuscula es {nombre_completo.lower()}")              # convierte la cadena a Minusculas con metodo lower() e imprime
print("")
total_caracter = len(nombre_completo.replace(" ", ""))                               # devuelve el total de caracteres reemplazando los espacios con metodo replace()
print(f"El Total de caracteres sin contar los espacios en tu Nombre completo es {total_caracter} !")         # Imprime el total de caracteres
print("")
nuevo_nombre = nombre_completo.replace("Dante", "Daniel")                           # se reemplaza el primer nombre por nuevo_nombre con metodo replace()
print(f"Tu nuevo Nombre completo es {nuevo_nombre}!")
# Out:
# Tu Nombre completo en Mayuscula es DANTE GINO SILVA SANTIS
#
# Tu Nombre completo en Minuscula es dante gino silva santis
#
# El Total de caracteres sin contar los espacios en tu Nombre completo es 20 !
#
# Tu nuevo Nombre completo es Daniel Gino Silva Santis!

# %% [markdown]
# ## Ejercicio 3 : Lista de Nombres

# %%
lista = input("Ingrese una Lista de nombres separados por comas : ")       # se ingresa los nombres con input separados por ","
lista_nombres = lista.split(",")                                         # se convierte el texto en una lista con el metodo split(), dando la separacion con una coma
print("-- Lista de nombres -- :")
for nombre in lista_Nombres:
    print(nombre)
# Out:
# Ingrese una lista de nombres separados por ,  Juan,Pedro,Ana,Daniel
# Lista de nombres :
# Juan
# Pedro
# Ana
# Daniel
